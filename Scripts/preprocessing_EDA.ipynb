# %% [markdown]
# # Data Analysis Notebook
#
# This notebook combines data collection (scraping) and data preprocessing.
#
# Steps:
# 1. **Scrape** reviews from Google Play Store
# 2. **Preprocess** and clean the data
# 3. **Visualize** the results

# %%
import sys
import os
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Get the current working directory
current_dir = os.getcwd()
print(f"Current working directory: {current_dir}")

# Check if we need to change directory to the project root
if os.path.basename(current_dir) == 'Scripts':
    project_root = os.path.dirname(current_dir)
    os.chdir(project_root)
    print(f"Changed working directory to: {project_root}")
    sys.path.append(current_dir)
else:
    scripts_path = os.path.join(current_dir, 'Scripts')
    if os.path.exists(scripts_path):
        sys.path.append(scripts_path)

# Import modules
try:
    from preprocessing import ReviewPreprocessor
    try:
        from scraper import main as run_scraper
    except ImportError:
        from scraper import main as run_scraper
except ImportError as e:
    # Fallback logic if imports fail directly
    sys.path.append(os.getcwd())
    from preprocessing import ReviewPreprocessor
    from scraper import main as run_scraper
# Out:
# Current working directory: c:\Users\Eyasu\Documents\10th\customer-experience-analytics-for-fintech-apps-week2\Scripts
# Changed working directory to: c:\Users\Eyasu\Documents\10th\customer-experience-analytics-for-fintech-apps-week2

# %% [markdown]
# ## 1. Run Scraper
#
# This cell runs the scraping script to fetch the latest reviews from the Google Play Store.
# The output will show the progress.

# %%
print("🚀 Starting Scraper...")

# Run the main scraper function
raw_df = run_scraper()

print("\n✅ Scraping Finished.")
display(raw_df.head())
# Out:
# 🚀 Starting Scraper...
# ============================================================
# Starting Google Play Store Review Scraper
# ============================================================
#
# [1/2] Fetching app information...
#
# CBE: Commercial Bank of Ethiopia
# App ID: com.combanketh.mobilebanking
# Current Rating: 4.3207545
# Total Ratings: 38837
# Total Reviews: 8334
#
# BOA: Bank of Abyssinia
# App ID: com.boa.boaMobileBanking
# Current Rating: 4.192488
# Total Ratings: 6326
# Total Reviews: 1219
#
# DB: Dashin Bank
# App ID: com.dashen.dashensuperapp
# Current Rating: 4.1683674
# Total Ratings: 3898
# Total Reviews: 770
#
# App information saved to data/raw/app_info.csv
#
# [2/2] Scraping reviews...
# Banks:   0%|          | 0/3 [00:00<?, ?it/s]
# Scraping reviews for com.combanketh.mobilebanking...
# Successfully scraped 400 reviews
# Collected 400 reviews for Commercial Bank of Ethiopia
# Banks:  33%|███▎      | 1/3 [00:07<00:14,  7.38s/it]
# Scraping reviews for com.boa.boaMobileBanking...
# Successfully scraped 400 reviews
# Collected 400 reviews for Bank of Abyssinia
# Banks:  67%|██████▋   | 2/3 [00:11<00:05,  5.55s/it]
# Scraping reviews for com.dashen.dashensuperapp...
# Successfully scraped 400 reviews
# Collected 400 reviews for Dashin Bank
# Banks: 100%|██████████| 3/3 [00:17<00:00,  5.74s/it]
# ============================================================
# Scraping Complete!
# ============================================================
#
# Total reviews collected: 1200
# Reviews per bank:
#   Commercial Bank of Ethiopia: 400
#   Bank of Abyssinia: 400
#   Dashin Bank: 400
#
# Data saved to: data/raw/reviews_raw.csv
#
# ============================================================
# Sample Reviews
# ============================================================
#
# Commercial Bank of Ethiopia:
# ------------------------------------------------------------
#
# Rating: ⭐⭐⭐⭐⭐
# Review: good app...
# Date: 2025-11-28 11:33:17
#
# Rating: ⭐⭐⭐⭐⭐
# Review: This application is very important and advantage for transfer of money and finance in the coutry and foriegn country....
# Date: 2025-11-27 23:08:20
#
# Rating: ⭐
# Review: why didn't work this app?...
# Date: 2025-11-27 22:40:35
#
# Bank of Abyssinia:
# ------------------------------------------------------------
#
# Rating: ⭐⭐⭐⭐⭐
# Review: good jop...
# Date: 2025-11-27 13:19:25
#
# Rating: ⭐
# Review: bad exprience...it is so crushed...
# Date: 2025-11-27 11:41:15
#
# Rating: ⭐
# Review: not user friendly at all it requires a huge connectivity and also lags many times 😑😑😑...
# Date: 2025-11-26 22:52:50
#
# Dashin Bank:
# ------------------------------------------------------------
#
# Rating: ⭐⭐⭐⭐
# Review: It Is An Amazing app...
# Date: 2025-11-28 09:44:21
#
# Rating: ⭐⭐⭐⭐⭐
# Review: its fast and easy to communicate to the app and its available all area keep it up.i will make Happy for this application thank you dashen bank for your effort,commitment and dedication. i appricated y...
# Date: 2025-11-26 18:02:58
#
# Rating: ⭐
# Review: What do you care about my phone's settings? Who are you to tell me what to turn off and on? It is my phone after all. This *develoler option* thing will cost you a lot of users who are willing to leav...
# Date: 2025-11-25 17:03:10
#
# ✅ Scraping Finished.
#                               review_id  \
# 0  ee0dbb0e-4eb0-47b5-9874-c37877493f99
# 1  5112423d-e618-44ba-ba49-62677cb76cd6
# 2  bcb34681-1dd4-4781-b400-4393bb10b1d9
# 3  c69f051a-00f8-4144-8423-b7ebcd328d2d
# 4  d2995fb9-63c6-4bfc-8d3c-93a0ee9dba8f
#
#                                          review_text  rating  \
# 0                                           good app       5
# 1  This application is very important and advanta...       5
# 2                          why didn't work this app?       1
# 3      The app makes our life easier. Thank you CBE!       5
# 4                                this app very bad 👎       1
#
#           review_date         user_name  thumbs_up reply_content bank_code  \
# 0 2025-11-28 11:33:17   Betelhem Kebede          0          None       CBE
# 1 2025-11-27 23:08:20    Gurawaa Dooguu          0          None       CBE
# 2 2025-11-27 22:40:35  Yohannesb Adugna          0          None       CBE
# 3 2025-11-27 18:00:06  Mohammed Abrahim          0          None       CBE
# 4 2025-11-27 16:28:10    Sulxaan Huseen          0          None       CBE
#
#                      bank_name app_id       source
# 0  Commercial Bank of Ethiopia   None  Google Play
# 1  Commercial Bank of Ethiopia   None  Google Play
# 2  Commercial Bank of Ethiopia  5.2.1  Google Play
# 3  Commercial Bank of Ethiopia  5.2.1  Google Play
# 4  Commercial Bank of Ethiopia   None  Google Play

# %% [markdown]
# ## 2. Run Preprocessing Pipeline
#
# Now we clean the scraped data using our `ReviewPreprocessor`.

# %%
# Initialize the preprocessor
preprocessor = ReviewPreprocessor()

# Run the process
success = preprocessor.process()

if success:
    print("\n✅ Preprocessing finished successfully!")
    df = preprocessor.df
else:
    print("❌ Preprocessing failed.")
# Out:
# ============================================================
# STARTING DATA PREPROCESSING
# ============================================================
# Loading raw data...
# Loaded 1200 reviews
#
# [1/6] Checking for missing data...
#
# Missing values:
#   reply_content: 1198 (99.83%)
#   app_id: 273 (22.75%)
#
# [2/6] Handling missing values...
#
# [3/6] Normalizing dates...
# Date range: 2024-09-30 to 2025-11-28
#
# [4/6] Cleaning text...
#
# [5/6] Validating ratings...
# All ratings are valid (1-5)
#
# [6/6] Preparing final output...
# Final dataset: 1200 reviews
#
# Saving processed data...
# Data saved to: data/processed/reviews_processed.csv
#
# ============================================================
# PREPROCESSING REPORT
# ============================================================
#
# Original records: 1200
# Records with missing critical data: 0
# Empty reviews removed: 0
# Invalid ratings removed: 0
# Final records: 1200
#
# Data retention rate: 100.00%
# Data error rate: 0.00%
# ✓ Data quality: EXCELLENT (<5% errors)
#
# Reviews per bank:
#   Bank of Abyssinia: 400
#   Commercial Bank of Ethiopia: 400
#   Dashin Bank: 400
#
# Rating distribution:
#   ⭐⭐⭐⭐⭐: 733 (61.1%)
#   ⭐⭐⭐⭐: 90 (7.5%)
#   ⭐⭐⭐: 66 (5.5%)
#   ⭐⭐: 45 (3.8%)
#   ⭐: 266 (22.2%)
#
# Date range: 2024-09-30 to 2025-11-28
#
# Text statistics:
#   Average length: 52 characters
#   Median length: 17 characters
#   Min length: 1
#   Max length: 500
#
# ✅ Preprocessing finished successfully!

# %% [markdown]
# ## 3. Visualizations
#
# Let's explore the cleaned data.

# %%
# Set plot style
sns.set(style="whitegrid")
plt.figure(figsize=(12, 5))

# 1. Ratings Distribution
plt.subplot(1, 2, 1)
sns.countplot(x='rating', data=df, palette='viridis')
plt.title('Distribution of Ratings')
plt.xlabel('Star Rating')
plt.ylabel('Count')

# 2. Reviews per Bank
plt.subplot(1, 2, 2)
sns.countplot(x='bank_code', data=df, palette='Set2')
plt.title('Number of Reviews per Bank')
plt.xlabel('Bank')
plt.ylabel('Count')

plt.tight_layout()
plt.show()
# Out:
# C:\Users\Eyasu\AppData\Local\Temp\ipykernel_6960\307724874.py:7: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x='rating', data=df, palette='viridis')
# C:\Users\Eyasu\AppData\Local\Temp\ipykernel_6960\307724874.py:14: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x='bank_code', data=df, palette='Set2')

# %%
# 3. Review Length Distribution
plt.figure(figsize=(10, 6))
sns.histplot(data=df, x='text_length', bins=50, kde=True, hue='bank_code')
plt.title('Distribution of Review Lengths by Bank')
plt.xlabel('Review Length (characters)')
plt.ylabel('Count')
plt.show()

# %%
# NEW CELL: Post-Processing Duplicate Check
print("Post-Duplicate Check:")
print(f"Unique review_ids: {df['review_id'].nunique()}/{len(df)}")
assert df['review_id'].nunique() == len(df), "Duplicates detected!"
# Out:
# Post-Duplicate Check:
# Unique review_ids: 1200/1200

# %%
# NEW: Save Report to MD for README
report_md = """
# Preprocessing Report
- Original: {original}
- Final: {final}
- Retention: {retention:.2f}%
""".format(original=preprocessor.stats.get('original_count', 0), final=preprocessor.stats.get('final_count', 0), retention=(preprocessor.stats.get('final_count', 0) / preprocessor.stats.get('original_count', 1)) * 100)

with open('Scripts/README.md', 'w') as f:
    f.write(report_md)
os.makedirs('reports', exist_ok=True)
print("Report saved to Scripts/README.md")
# Out:
# Report saved to Scripts'README.md
